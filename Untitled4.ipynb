# %%
Q1, Create a vehicle class with an init method having instance variables as name_of_vehicle, max_speed
and average_of_vehicle.
class Vehicle:
    def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_of_vehicle = average_of_vehicle

# Create instances of the Vehicle class
vehicle1 = Vehicle("Car", 200, 30)
vehicle2 = Vehicle("Bike", 120, 40)

# Access instance variables
print("Vehicle 1:")
print("Name:", vehicle1.name_of_vehicle)
print("Max Speed:", vehicle1.max_speed)
print("Average Speed:", vehicle1.average_of_vehicle)

print("\nVehicle 2:")
print("Name:", vehicle2.name_of_vehicle)
print("Max Speed:", vehicle2.max_speed)
print("Average Speed:", vehicle2.average_of_vehicle)

# %%
Q2. Create a child class car from the vehicle class created in Que 1, which will inherit the vehicle class.
Create a method named seating_capacity which takes capacity as an argument and returns the name of
the vehicle and its seating capacity.
class Vehicle:
    def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_of_vehicle = average_of_vehicle

class Car(Vehicle):
    def seating_capacity(self, capacity):
        return f"{self.name_of_vehicle} has a seating capacity of {capacity} passengers."

# Create an instance of the Car class
car1 = Car("Sedan", 180, 5)

# Access instance variables and call the seating_capacity method
print("Car 1:")
print("Name:", car1.name_of_vehicle)
print("Max Speed:", car1.max_speed)
print("Average Speed:", car1.average_of_vehicle)
print(car1.seating_capacity(5))

# %%
Q3. What is multiple inheritance? Write a python code to demonstrate multiple inheritance.
Multiple inheritance is a feature in object-oriented programming that allows a class to inherit attributes and methods from more than one parent class. In other words, a class can inherit properties and behaviors from multiple superclasses. This allows for greater flexibility in creating complex class hierarchies and reusing code.


# Parent class 1
class Bird:
    def __init__(self):
        self.wings = 2

    def fly(self):
        print("Flying with wings")

# Parent class 2
class Mammal:
    def __init__(self):
        self.legs = 4

    def walk(self):
        print("Walking on four legs")

# Child class inheriting from both Bird and Mammal
class Bat(Bird, Mammal):
    def __init__(self):
        # Call constructors of both parent classes
        Bird.__init__(self)
        Mammal.__init__(self)

    def fly(self):
        print("Flying like a bat")

    def echo_location(self):
        print("Using echolocation")

# Create an instance of the Bat class
bat = Bat()

# Access attributes and call methods
print("Bat has", bat.wings, "wings and", bat.legs, "legs.")
bat.walk()  # Calls the walk() method from Mammal
bat.fly()   # Calls the fly() method from Bat
bat.echo_location()

# %%
Q4. What are getter and setter in python? Create a class and create a getter and a setter method in this
class.
In Python, getters and setters are methods used to access and modify the private attributes (variables) of a class. They are used to control the encapsulation of data, allowing you to define how data should be accessed and modified, while providing an additional layer of abstraction and control over the data. Getter methods are used to retrieve the value of an attribute,
while setter methods are used to modify the value of an attribute.
